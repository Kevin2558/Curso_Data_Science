# %% [markdown]
# <a href="https://colab.research.google.com/github/GillValenzuela/curso_data_science/blob/master/Roc%C3%ADoVillavicencio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TALLER 1

# %% [markdown]
# Sección 0

# %%
# !pip install outdated pingouin mistat KDEpy --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.4/204.4 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 12.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.5/687.5 kB 30.2 MB/s eta 0:00:00
# ...

# %%
import pandas as pd # importo librerías útiles
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Sección 1

# %%
df = pd.read_csv('/content/sample_data/titanic-dataset.csv') # cargo el archivo

# %%
df.head(5) # muestro las primeras 5 filas
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape # obtengo la dimensión
# Out:
# (891, 12)

# %%
df.info # obtengo información (estructura)
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.describe # obtengo una descripción estadística
# Out:
# <bound method NDFrame.describe of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.columns # obtengo los nombres de las columnas
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes # verifico los "tipos" (entero, flotante, etc)
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# Passenger ID: Nos entrega un número único que representa a cada persona, puede servir como identificador encriptado o para conectar data \\
# Survived: Nos señala de forma binaria si una persona sobrevivió o no \\
# Pclass: Clase, nos permite agrupar por clase a las personas \\
# Name: Nombre \\
# Sex: Sexo \\
# Age: Edad \\
# SibSp:  \\
# Parch:  \\
# Ticket: Ticket \\
# Fare: \\
# Cabin: Cabina \\
# Embarked: \\

# %% [markdown]
# Sección 2

# %%
df[['Age','Fare']].mean() # obtengo la media
# Out:
# Age     29.699118
# Fare    32.204208
# dtype: float64

# %%
df[['Age','Fare']].median() # obtengo la mediana
# Out:
# Age     28.0000
# Fare    14.4542
# dtype: float64

# %%
rango = df['Age'].max() - df['Age'].min() # rango de la edad
print(rango)
# Out:
# 79.58

# %%
desviacion_estandar = df['Age'].std() # desviación estandar de la edad
print(desviacion_estandar)
# Out:
# 14.526497332334044

# %%
df.isnull().sum() # indica cantidad de valores nulos
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Edad y cabina tiene muchos valores nulos. Una posible solución al problema se me ocurre repetir el promedio para que estos no desvíen los datos

# %%
df["Age"].fillna(df["Age"].median(), inplace=True
# Out:
#   File "<ipython-input-32-c8d5f129bb49>", line 1
#     df["Age"].fillna(df["Age"].median(), inplace=True
#                                                      ^
# SyntaxError: incomplete input
